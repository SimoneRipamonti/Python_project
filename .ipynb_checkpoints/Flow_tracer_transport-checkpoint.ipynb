# %%
import numpy as np
import porepy as pp
import scipy.sparse as sps
import sys
sys.path.append("./class")
from Flow_class import Flow
from Transport_class import Transport

# %%
mesh_args = {"mesh_size_frac": 0.15, "mesh_size_bound": 0.15}
gb, domain = pp.grid_buckets_2d.benchmark_regular(mesh_args)
parameter={"aperture":1e-3,
          "fracture_perm":1e4,
          "perm":1,
          "f_lambda":lambda x,y,z:math.pi*math.pi*2*math.sin(math.pi*x)*math.sin(math.pi*y),
          "bc_value":[0.0,0.0],
          "bc_type":['dir','dir'],
          "method":"Tpfa"}

# %%
flow=Flow(gb,domain,parameter)
flow.add_data()
flow.discretize()
flow.solve()
flow.plot_pressure()

# %%
parameter={
    "aperture":1e-4,
    "por":0.2,
    "por_frac":0.8,
    "time_step":1 / 60,
    "t_max":1 /3,
    "bc_value"=[1.0,0.0],
    "bc_type"=['dir','dir'],
    "initial_cond":lambda x,y,z:0.0}

transport=Transport(gb,domain,parameter)
transport.set_data(bc_value,bc_type,'transport')
transport.get_flux()
transport.discretize()
lhs,rhs_source_adv,rhs_mass,assembler=transport.get_transport_lhs_rhs()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-a0a9103a296c> in <module>
#      12 transport.get_flux()
#      13 transport.discretize()
# ---> 14 lhs,rhs_source_adv,rhs_mass,assembler=transport.get_transport_lhs_rhs()
#
# ~/Scrivania/Python_project/class/Transport_class.py in get_transport_lhs_rhs(self)
#     132
#     133         assembler.discretize(filt=filt)
# --> 134         A, b = assembler.assemble_matrix_rhs(filt=filt, add_matrices=False)
#     135
#     136         # Identifier of the discretization operator on each grid
#
# ~/anaconda3/lib/python3.8/site-packages/porepy/utils/logging.py in log_time(*args, **kwargs)
#     105                 # Shortcut if logging is not activated.
#     106                 # This is
# --> 107                 return func(*args, **kwargs)
#     108             elif always_log or any([s in active_sections for s in sections]):
#     109
#
# ~/anaconda3/lib/python3.8/site-packages/porepy/numerics/mixed_dim/assembler.py in assemble_matrix_rhs(self, filt, matrix_format, add_matrices, only_matrix, only_rhs)
#     205
#     206         # Assemble
# --> 207         matrix, rhs = self._operate_on_gb(  # type:ignore
#     208             operation="assemble",
#     209             filt=filt,
#
# ~/anaconda3/lib/python3.8/site-packages/porepy/utils/logging.py in log_time(*args, **kwargs)
#     105                 # Shortcut if logging is not activated.
#     106                 # This is
# --> 107                 return func(*args, **kwargs)
#     108             elif always_log or any([s in active_sections for s in sections]):
#     109
#
# ~/anaconda3/lib/python3.8/site-packages/porepy/numerics/mixed_dim/assembler.py in _operate_on_gb(self, operation, filt, **kwargs)
#     394
#     395         # First take care of operations internal to nodes and edges
# --> 396         self._operate_on_nodes_and_edges(filt, operation, matrix, rhs, **extra_args)
#     397
#     398         # Next, handle coupling over edges
#
# ~/anaconda3/lib/python3.8/site-packages/porepy/utils/logging.py in log_time(*args, **kwargs)
#     105                 # Shortcut if logging is not activated.
#     106                 # This is
# --> 107                 return func(*args, **kwargs)
#     108             elif always_log or any([s in active_sections for s in sections]):
#     109
#
# ~/anaconda3/lib/python3.8/site-packages/porepy/numerics/mixed_dim/assembler.py in _operate_on_nodes_and_edges(self, filt, operation, matrix, rhs, assemble_matrix_only, assemble_rhs_only)
#     473                 else:
#     474                     if is_node:
# --> 475                         loc_A, loc_b = discr.assemble_matrix_rhs(grid, data)
#     476                     else:
#     477                         loc_A, loc_b = discr.assemble_matrix_rhs(data)
#
# ~/anaconda3/lib/python3.8/site-packages/porepy/utils/logging.py in log_time(*args, **kwargs)
#     105                 # Shortcut if logging is not activated.
#     106                 # This is
# --> 107                 return func(*args, **kwargs)
#     108             elif always_log or any([s in active_sections for s in sections]):
#     109
#
# ~/anaconda3/lib/python3.8/site-packages/porepy/numerics/fv/source.py in assemble_matrix_rhs(self, g, data)
#      73             source values are assumed to be integrated over the cell volumes.
#      74         """
# ---> 75         return self.assemble_matrix(g, data), self.assemble_rhs(g, data)
#      76
#      77     @pp.time_logger(sections=module_sections)
#
# ~/anaconda3/lib/python3.8/site-packages/porepy/utils/logging.py in log_time(*args, **kwargs)
#     105                 # Shortcut if logging is not activated.
#     106                 # This is
# --> 107                 return func(*args, **kwargs)
#     108             elif always_log or any([s in active_sections for s in sections]):
#     109
#
# ~/anaconda3/lib/python3.8/site-packages/porepy/numerics/fv/source.py in assemble_rhs(self, g, data)
#     113         parameter_dictionary = data[pp.PARAMETERS][self.keyword]
#     114
# --> 115         sources = parameter_dictionary["source"]
#     116         assert sources.size == self.ndof(
#     117             g
#
# KeyError: 'source'

# %%
save_every = 1
n_steps = int(np.round(parameter["t_max"] / parameter["time_step"]))

# Initial condition
tracer = np.zeros(rhs_source_adv.size)
assembler.distribute_variable(
    tracer, variable_names=[transport.grid_variable,transport.mortar_variable]
)


# Exporter
exporter = pp.Exporter(gb, file_name="tracer", folder_name="Tracer")
export_fields = ["tracer"]
IEsolver = sps.linalg.factorized(lhs)

# %%
for i in range(n_steps):
    
    if np.isclose(i % save_every, 0):
        # Export existing solution (final export is taken care of below)
        assembler.distribute_variable(
        tracer,
        variable_names=[transport.grid_variable,transport.mortar_variable],
    )
        exporter.write_vtu(export_fields, time_step=int(i // save_every))
    tracer = IEsolver(rhs_mass * tracer + rhs_source_adv)

    
exporter.write_vtu(export_fields, time_step=(n_steps // save_every))
time_steps = np.arange(
    0, parameter["t_max"] + parameter["time_step"], save_every * parameter["time_step"]
)
exporter.write_pvd(time_steps)
transport.plot_tracer()
